# %%
import pandas as pd
import altair as alt
import numpy as np

# %%
csv_url = 'https://raw.githubusercontent.com/n2cholas/dsc-workshops/master/Intro_to_Interactive_Data_Viz_with_Altair/pokemon-data-cleaned.csv'
df = pd.read_csv(csv_url, na_filter=False)

# %%
df.sample()
# Out:
#           Name  Tier  Num Types  Type 1 Type 2  Num Abilities     Ability 1  \
# 610  Porygon-Z  UUBL          1  Normal                     3  Adaptability
#
#     Ability 2 Ability 3  Has Negative Ability  ...  \
# 610  Analytic  Download                     0  ...
#
#      Max Offensive Boost Amount  Recovery Moves  Priority STAB Attacks  \
# 610                           2     {'Recover'}                  set()
#
#      Entry Hazards  Hazard Clearing Moves  Phazing Moves  Switch Attacks  \
# 610          set()                  set()          set()           set()
#
#       High Prob Side FX Attacks  Constant Damage Attacks  Trapping Moves
# 610  {'Discharge', 'Iron Tail'}                    set()           set()
#
# [1 rows x 38 columns]

# %%
df.sample()
# Out:
#        Name Tier  Num Types  Type 1 Type 2  Num Abilities Ability 1 Ability 2  \
# 261  Furret   PU          1  Normal                     3     Frisk  Keen Eye
#
#     Ability 3  Has Negative Ability  ...  Max Offensive Boost Amount  \
# 261  Run Away                     0  ...                           2
#
#      Recovery Moves  Priority STAB Attacks  Entry Hazards  \
# 261           set()                  set()          set()
#
#      Hazard Clearing Moves  Phazing Moves  Switch Attacks  \
# 261                  set()          set()      {'U-turn'}
#
#                   High Prob Side FX Attacks  Constant Damage Attacks  \
# 261  {'Body Slam', 'Headbutt', 'Iron Tail'}                    set()
#
#      Trapping Moves
# 261           set()
#
# [1 rows x 38 columns]

# %%
# Narrow scope of data
df.loc[df['Tier'] == 'OUBL','Tier'] = 'Uber'
df.loc[df['Tier'] == 'UUBL','Tier'] = 'OU'
df.loc[df['Tier'] == 'RUBL','Tier'] = 'UU'
df.loc[df['Tier'] == 'NUBL','Tier'] = 'RU'
df.loc[df['Tier'] == 'PUBL','Tier'] = 'NU'
df = df[df['Tier'].isin(['Uber', 'OU', 'UU', 'NU', 'RU', 'PU'])]

# %%
df.drop(['Num Types', 'Type 1', 'Type 2', 'Num Abilities',
        'Ability 1', 'Ability 2', 'Ability 3', 'Has Negative Ability', 'HP',
        'Attack', 'Defense', 'Special Attack', 'Special Defense', 'Speed',
        'Next Evolution(s)', 'Evolutionary Stage',
        'Num Evolutionary Stages', 'Evolutionary Progress', 'Is Mega Evolution',
        'Is Alternate Form', 'Moves', 'Defensive Boost Moves',
        'Offensive Boost Moves', 'Max Defensive Boost Amount',
        'Max Offensive Boost Amount', 'Recovery Moves', 'Priority STAB Attacks',
        'Entry Hazards', 'Hazard Clearing Moves', 'Phazing Moves',
        'Switch Attacks', 'High Prob Side FX Attacks',
        'Constant Damage Attacks', 'Trapping Moves'], axis=1, inplace=True)

df.sample()
# Out:
# C:\Users\Jesper\AppData\Local\Temp\ipykernel_19292\2220059755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Num Types', 'Type 1', 'Type 2', 'Num Abilities',
#                Name Tier  Base Stat Total  Num Moves
# 270  Gardevoir-Mega   OU              618        101

# %%
alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='Num Moves',
    color='Tier',
    tooltip='Name'
).properties(
    title='Pokemon Data'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point()
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x=alt.X('Base Stat Total', bin=True),
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x=alt.X('Base Stat Total', bin=alt.Bin(maxbins=30)),
    y='count()', 
    color='Tier',
    column='Tier'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x='average(Base Stat Total)',
    y='Tier', 
    color='Tier'

)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x='average(Base Stat Total)',
    y='Tier', 
    color='Tier'

)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    x='Base Stat Total:Q',
    y='Num Moves:Q',
    color='Tier:N'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Interaction

# %%
alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='Num Moves', 
    color='Tier'
).interactive()
# Out:
# alt.Chart(...)

# %%
interval= alt.selection_interval()

alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='Num Moves', 
    color='Tier'
).properties(
    selection=interval
)
# Out:
# alt.Chart(...)

# %%
interval= alt.selection_interval(encodings=['y'])

alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='Num Moves', 
    color=alt.condition(interval,'Tier', alt.value('lightgray'))
).properties(
    selection=interval
)
# Out:
# alt.Chart(...)

# %%
interval= alt.selection_interval(encodings=['y'])

scatter= alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='Num Moves', 
    color=alt.condition(interval,'Tier', alt.value('lightgray'))
).properties(
    selection=interval
)

bar= alt.Chart(df).mark_bar().encode(
    x='count()',
    y='Tier',
    color='Tier'
).transform_filter(
    interval
)

# %%
scatter & bar
# Out:
# alt.VConcatChart(...)

# %%
multi = alt.selection_multi(fields=['Tier'])

scatter = alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='Num Moves',
    color=alt.condition(multi, 'Tier', alt.value('lightgray'))
)

bar = alt.Chart(df).mark_bar().encode(
    x='average(Base Stat Total)',
    y='Tier',
    color=alt.condition(multi, 'Tier', alt.value('lightgray'))
).properties(
    selection=multi
)

scatter & bar
# Out:
# alt.VConcatChart(...)

# %%
multi = alt.selection_multi(fields=['Tier'])
interval = alt.selection_interval(encodings=['y'])
scatter = alt.Chart(df).mark_point().encode(
    x='Base Stat Total',
    y='Num Moves',
    color=alt.condition(multi, 'Tier', alt.value('lightgray'))
).properties(
    selection=interval
)

bar = alt.Chart(df).mark_bar().encode(
    x='average(Base Stat Total)',
    y='Tier',
    color=alt.condition(multi, 'Tier', alt.value('lightgray'))
).properties(
    selection=multi
).transform_filter(
    interval
)

scatter & bar
# Out:
# alt.VConcatChart(...)
